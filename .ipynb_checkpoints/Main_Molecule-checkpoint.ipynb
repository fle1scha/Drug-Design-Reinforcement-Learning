# %% [markdown]
# # Main class for running the molecule environment

# %%
import gym
from gym import wrappers, logger
from MoleculeAgent import MoleculeAgent
# TODO: prompt user when wrong goal entered
# import chem, make a mol object valid and only move from there.
# Add pop in modifications

# %%
def main():   
    # Get input goal and start state from user
    goal = input("Enter a molecule to act as an optimisation Goal. \n for a random molecule enter '1' ")
    if goal == "1":
        mol = 1
    else: 
        mol = input("Enter an atom or molecule to act as the start state of the environment: ")
       
    env = gym.make("gym_molecule:molecule-v0", mol = mol, goal= goal)
    print("Environment initialiased.")
    #Create a new Molecule Agent object. 
    agent = MoleculeAgent(env.action_space)
    
    
    episode_count = 3
    reward = 0
    done = False

    #The 'RL algorithm' learns for 2 episodes of undefined length.
    for i in range(0, episode_count):
        print("EPISODE:", i)
        
        #The env resets.
        ob = env.reset()
        print("Env original state: ", ob)
        
        #While what is True? Maybe While done is False?
        for x in range(20):
            
            #The agent chooses its action based on the tuple from the current env state.
            action = agent.act(ob, reward, done)
            print()
            print("Agent's chosen action: ", action) 
            
            #The new tuple is returned because the env has considered the agent's action.
            ob, reward, done, _ = env.step(action)
            print("Env new state:", ob, "Reward to agent:",reward, "Done:",done, "Info: ", _)
            
            #The env renders. 
            env.render()
            
            
        
            #If the env reaches a terminating state, the current iteration ends and the next 
            #episode begins. 
            """"if done:
                print()
                break"""
        
    env.close()
    
    
if __name__ == '__main__':
    main()
# Out:
# Enter a molecule to act as an optimisation Goal.
#  for a random molecule enter '1' FFF
# Enter an atom or molecule to act as the start state of the environment: FFF
# RDKit ERROR: [12:09:59] Explicit valence for atom # 1 F, 2, is greater than permitted
# invalid Goal: choosing a random one from SMILES dataset.
# Environment initialiased.
# EPISODE: 0
# Env original state:  None
#
# Agent's chosen action:  2
# ['C']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  4
# add bracketed atom
# ['C', 'bracketed atom']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  1
# ['C', 'bracketed atom', 'C']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  1
# ['C', 'bracketed atom', 'C', 'C']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  2
# ['C', 'bracketed atom', 'C', 'C', 'N']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  2
# ['C', 'bracketed atom', 'C', 'C', 'N', 'C']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  5
# add ring
# ['C', 'bracketed atom', 'C', 'C', 'N', 'C', 'ring']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  0
# ['C', 'bracketed atom', 'C', 'C', 'N', 'C', 'ring', 'C']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  3
# ['C', 'bracketed atom', 'C', 'C', 'N', 'C', 'ring', 'C', 'C']
# calculating Reward
# Env new state: 0.6623 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  0
# ['C', 'bracketed atom', 'C', 'C', 'N', 'C', 'ring', 'C', 'C', 'N']
# calculating Reward
# Env new state: 0.6211 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  0
# ['C', 'bracketed atom', 'C', 'C', 'N', 'C', 'ring', 'C', 'C', 'N', 'N']
# calculating Reward
# Env new state: 0.6211 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  2
# ['C', 'bracketed atom', 'C', 'C', 'N', 'C', 'ring', 'C', 'C', 'N', 'N', 'C']
# calculating Reward
# Env new state: 0.6623 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  2
# ['C', 'bracketed atom', 'C', 'C', 'N', 'C', 'ring', 'C', 'C', 'N', 'N', 'C', 'C']
# calculating Reward
# Env new state: 0.625 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  0
# ['C', 'bracketed atom', 'C', 'C', 'N', 'C', 'ring', 'C', 'C', 'N', 'N', 'C', 'C', 'N']
# calculating Reward
# Env new state: 1.2658 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  5
# add ring
# ['C', 'bracketed atom', 'C', 'C', 'N', 'C', 'ring', 'C', 'C', 'N', 'N', 'C', 'C', 'N', 'ring']
# calculating Reward
# Env new state: 1.2658 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  2
# ['C', 'bracketed atom', 'C', 'C', 'N', 'C', 'ring', 'C', 'C', 'N', 'N', 'C', 'C', 'N', 'ring', 'C']
# calculating Reward
# Env new state: 1.25 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  1
# ['C', 'bracketed atom', 'C', 'C', 'N', 'C', 'ring', 'C', 'C', 'N', 'N', 'C', 'C', 'N', 'ring', 'C', 'N']
# calculating Reward
# Env new state: 1.2658 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  1
# ['C', 'bracketed atom', 'C', 'C', 'N', 'C', 'ring', 'C', 'C', 'N', 'N', 'C', 'C', 'N', 'ring', 'C', 'N', 'C']
# calculating Reward
# Env new state: 1.25 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  3
# ['C', 'bracketed atom', 'C', 'C', 'N', 'C', 'ring', 'C', 'C', 'N', 'N', 'C', 'C', 'N', 'ring', 'C', 'N', 'C', 'N']
# calculating Reward
# Env new state: 1.7647 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  4
# add bracketed atom
# ['C', 'bracketed atom', 'C', 'C', 'N', 'C', 'ring', 'C', 'C', 'N', 'N', 'C', 'C', 'N', 'ring', 'C', 'N', 'C', 'N', 'bracketed atom']
# calculating Reward
# Env new state: 1.7647 Reward to agent: 1 Done: False Info:  {}
# EPISODE: 1
# Env original state:  None
#
# Agent's chosen action:  1
# ['N']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  4
# add bracketed atom
# ['N', 'bracketed atom']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  0
# ['N', 'bracketed atom', 'C']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  2
# ['N', 'bracketed atom', 'C', 'C']
# calculating Reward
# Env new state: 0.7752 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  4
# add bracketed atom
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom']
# calculating Reward
# Env new state: 0.7752 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  0
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom', 'N']
# calculating Reward
# Env new state: 0.7519 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  4
# add bracketed atom
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom', 'N', 'bracketed atom']
# calculating Reward
# Env new state: 0.7752 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  2
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom', 'N', 'bracketed atom', 'C']
# calculating Reward
# Env new state: 0.7407 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  3
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom', 'N', 'bracketed atom', 'C', 'C']
# calculating Reward
# Env new state: 0.7519 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  5
# add ring
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom', 'N', 'bracketed atom', 'C', 'C', 'ring']
# calculating Reward
# Env new state: 0.7752 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  0
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom', 'N', 'bracketed atom', 'C', 'C', 'ring', 'C']
# calculating Reward
# Env new state: 0.7407 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  2
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom', 'N', 'bracketed atom', 'C', 'C', 'ring', 'C', 'N']
# calculating Reward
# Env new state: 0.7519 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  2
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom', 'N', 'bracketed atom', 'C', 'C', 'ring', 'C', 'N', 'N']
# calculating Reward
# Env new state: 0.7519 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  1
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom', 'N', 'bracketed atom', 'C', 'C', 'ring', 'C', 'N', 'N', 'N']
# calculating Reward
# Env new state: 2.2556 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  5
# add ring
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom', 'N', 'bracketed atom', 'C', 'C', 'ring', 'C', 'N', 'N', 'N', 'ring']
# calculating Reward
# Env new state: 2.2556 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  4
# add bracketed atom
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom', 'N', 'bracketed atom', 'C', 'C', 'ring', 'C', 'N', 'N', 'N', 'ring', 'bracketed atom']
# calculating Reward
# Env new state: 2.2556 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  0
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom', 'N', 'bracketed atom', 'C', 'C', 'ring', 'C', 'N', 'N', 'N', 'ring', 'bracketed atom', 'N']
# calculating Reward
# Env new state: 2.1583 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  4
# add bracketed atom
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom', 'N', 'bracketed atom', 'C', 'C', 'ring', 'C', 'N', 'N', 'N', 'ring', 'bracketed atom', 'N', 'bracketed atom']
# calculating Reward
# Env new state: 2.2556 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  2
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom', 'N', 'bracketed atom', 'C', 'C', 'ring', 'C', 'N', 'N', 'N', 'ring', 'bracketed atom', 'N', 'bracketed atom', 'C']
# calculating Reward
# Env new state: 2.1277 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  0
# ['N', 'bracketed atom', 'C', 'C', 'bracketed atom', 'N', 'bracketed atom', 'C', 'C', 'ring', 'C', 'N', 'N', 'N', 'ring', 'bracketed atom', 'N', 'bracketed atom', 'C', 'C']
# calculating Reward
# Env new state: 2.1277 Reward to agent: 1 Done: False Info:  {}
# EPISODE: 2
# Env original state:  None
#
# Agent's chosen action:  5
# add ring
# ['ring']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  1
# ['ring', 'N']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  3
# ['ring', 'N', 'N']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  4
# add bracketed atom
# ['ring', 'N', 'N', 'bracketed atom']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  0
# ['ring', 'N', 'N', 'bracketed atom', 'C']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  3
# ['ring', 'N', 'N', 'bracketed atom', 'C', 'N']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  3
# ['ring', 'N', 'N', 'bracketed atom', 'C', 'N', 'C']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  0
# ['ring', 'N', 'N', 'bracketed atom', 'C', 'N', 'C', 'N']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  4
# add bracketed atom
# ['ring', 'N', 'N', 'bracketed atom', 'C', 'N', 'C', 'N', 'bracketed atom']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  0
# ['ring', 'N', 'N', 'bracketed atom', 'C', 'N', 'C', 'N', 'bracketed atom', 'N']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  5
# add ring
# ['ring', 'N', 'N', 'bracketed atom', 'C', 'N', 'C', 'N', 'bracketed atom', 'N', 'ring']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  4
# add bracketed atom
# ['ring', 'N', 'N', 'bracketed atom', 'C', 'N', 'C', 'N', 'bracketed atom', 'N', 'ring', 'bracketed atom']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  1
# ['ring', 'N', 'N', 'bracketed atom', 'C', 'N', 'C', 'N', 'bracketed atom', 'N', 'ring', 'bracketed atom', 'N']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  4
# add bracketed atom
# ['ring', 'N', 'N', 'bracketed atom', 'C', 'N', 'C', 'N', 'bracketed atom', 'N', 'ring', 'bracketed atom', 'N', 'bracketed atom']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  2
# ['ring', 'N', 'N', 'bracketed atom', 'C', 'N', 'C', 'N', 'bracketed atom', 'N', 'ring', 'bracketed atom', 'N', 'bracketed atom', 'N']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  2
# ['ring', 'N', 'N', 'bracketed atom', 'C', 'N', 'C', 'N', 'bracketed atom', 'N', 'ring', 'bracketed atom', 'N', 'bracketed atom', 'N', 'C']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  3
# ['ring', 'N', 'N', 'bracketed atom', 'C', 'N', 'C', 'N', 'bracketed atom', 'N', 'ring', 'bracketed atom', 'N', 'bracketed atom', 'N', 'C', 'C']
# calculating Reward
# Env new state: 0.0 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  3
# ['ring', 'N', 'N', 'bracketed atom', 'C', 'N', 'C', 'N', 'bracketed atom', 'N', 'ring', 'bracketed atom', 'N', 'bracketed atom', 'N', 'C', 'C', 'C']
# calculating Reward
# Env new state: 0.5405 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  4
# add bracketed atom
# ['ring', 'N', 'N', 'bracketed atom', 'C', 'N', 'C', 'N', 'bracketed atom', 'N', 'ring', 'bracketed atom', 'N', 'bracketed atom', 'N', 'C', 'C', 'C', 'bracketed atom']
# calculating Reward
# Env new state: 0.5405 Reward to agent: 1 Done: False Info:  {}
#
# Agent's chosen action:  0
# ['ring', 'N', 'N', 'bracketed atom', 'C', 'N', 'C', 'N', 'bracketed atom', 'N', 'ring', 'bracketed atom', 'N', 'bracketed atom', 'N', 'C', 'C', 'C', 'bracketed atom', 'N']
# calculating Reward
# Env new state: 0.5291 Reward to agent: 1 Done: False Info:  {}
