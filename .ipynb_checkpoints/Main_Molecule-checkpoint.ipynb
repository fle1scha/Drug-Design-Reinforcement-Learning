# %% [markdown]
# # Main class for running the molecule environment

# %%
import gym
from gym import wrappers, logger
from MoleculeAgent import MoleculeAgent
from rdkit import Chem
from rdkit.Chem import AllChem, Draw
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
# TODO: Render as a main function too
# Render toggled in the main class 
# find the correct time delay
# 
# Add pop in modifications

# %%
def validate(mol):
        try:
            molecule = Chem.MolFromSmiles(mol)
            smiles = Chem.MolToSmiles(molecule, isomericSmiles=True)
        except:
            print("Entered input is chemically invalid")
            return False
        else:
            
            return True


def main():   
    
    menu = input("1: Set Environment initial molecule and optimization goal. \n2: Use a Random set and initial moecule. \n")
    if menu == "2":  # Random goal
        mol = 1
        goal = 1
    elif menu == "1": # Cumstom inputs
        # Get valid input goal and start state from user
        validgoal = False
        validmol = False
        while validgoal == False: 
            goal = input("Enter a molecule to act as an optimisation Goal. \n ")
            validgoal = validate(goal)  

        while validmol == False:
            mol = input("Enter an atom or molecule to act as the start state of the environment: ")
            validmol = validate(mol)
            
    accuracy = float(input("Set the desired build similarity of your molecule:\n " + "%")) 
    
    env = gym.make("gym_molecule:molecule-v0", mol = mol, goal= goal, similarity = accuracy) # Instantiate environment
    print("Environment initialiased.")
     
    agent = MoleculeAgent(env.action_space) # Create a new Molecule Agent object.
    
    
    episode_count = 2
    reward = 0
    done = False

    #The 'RL algorithm' learns for 2 episodes of undefined length.
    for i in range(1, episode_count +1 ):
        print("EPISODE:", i)
        
        #The env resets.
        ob = env.reset()
        print("Env original state: ", ob)
        
        #While what is True? Maybe While done is False?
        for x in range(20):
            
            #The agent chooses its action based on the tuple from the current env state.
            action = agent.act(ob, reward, done)
            print()
            print("ACTION: ", action) 
            
            #The new tuple is returned because the env has considered the agent's action.
            ob, reward, done, _ = env.step(action)
            
            
            print("\nOBSERVED STATE:", ob, "\nREWARD:", reward, "\nDONE:", done,"\nINFO: ", _)
            
            #The env renders. 
            SMILES = env.render()
            Image = Draw.MolToImage(SMILES, size=(300, 300))
            ImageNumpyFormat = np.asarray(Image)
            plt.imshow(ImageNumpyFormat)
            plt.draw()
            plt.pause(0.5) # pause how many seconds
            plt.close()

            if done == True:
                print("Molecule Optimized.")
                break

            
        
            #If the env reaches a terminating state, the current iteration ends and the next 
            #episode begins. 

        
    env.close()
    
    
if __name__ == '__main__':
    main()

# Aspirin: O=C(C)Oc1ccccc1C(=O)O
# Start with: Oc1ccccc1C
# Out:
# 1: Set Environment initial molecule and optimization goal.
# 2: Use a Random set and initial moecule.
# 2
# Set the desired build similarity of your molecule:
#  %56
# invalid Goal: choosing a random one from SMILES dataset.
# Environment initialiased.
# EPISODE: 1
# Env original state:  None
#
# ACTION:  2
# ['Br']
#
# OBSERVED STATE: 14.2857
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  0
# ['Br', 'C', 'Reverted']
#
# OBSERVED STATE: 14.2857
# REWARD: REWARD
# DONE: False
# INFO:  {}
# RDKit ERROR: [23:19:49] Explicit valence for atom # 1 Br, 2, is greater than permitted
# ACTION:  3
# ['Br', 'C', 'Reverted', 'Br']
#
# OBSERVED STATE: 12.5
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  1
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br']
#
# OBSERVED STATE: 12.5
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  5
# add ring
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring']
#
# OBSERVED STATE: 14.2857
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  2
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring', 'Br', 'Reverted']
#
# OBSERVED STATE: 14.2857
# REWARD: REWARD
# DONE: False
# INFO:  {}
# RDKit ERROR: [23:19:52] Explicit valence for atom # 1 Br, 2, is greater than permitted
# ACTION:  1
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring', 'Br', 'Reverted', 'Br']
#
# OBSERVED STATE: 12.5
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  4
# add bracketed atom
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring', 'Br', 'Reverted', 'Br', 'Reverted', 'bracketed atom']
#
# OBSERVED STATE: 14.2857
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  1
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring', 'Br', 'Reverted', 'Br', 'Reverted', 'bracketed atom', 'Br']
#
# OBSERVED STATE: 12.5
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  1
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring', 'Br', 'Reverted', 'Br', 'Reverted', 'bracketed atom', 'Br', 'Reverted', 'C']
#
# OBSERVED STATE: 42.8571
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  2
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring', 'Br', 'Reverted', 'Br', 'Reverted', 'bracketed atom', 'Br', 'Reverted', 'C', 'C', 'Reverted']
#
# OBSERVED STATE: 42.8571
# REWARD: REWARD
# DONE: False
# INFO:  {}
# RDKit ERROR: [23:19:57] Explicit valence for atom # 2 Br, 2, is greater than permitted
# ACTION:  0
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring', 'Br', 'Reverted', 'Br', 'Reverted', 'bracketed atom', 'Br', 'Reverted', 'C', 'C', 'Reverted', 'C', 'Reverted']
#
# OBSERVED STATE: 42.8571
# REWARD: REWARD
# DONE: False
# INFO:  {}
# RDKit ERROR: [23:19:57] Explicit valence for atom # 2 Br, 2, is greater than permitted
# ACTION:  2
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring', 'Br', 'Reverted', 'Br', 'Reverted', 'bracketed atom', 'Br', 'Reverted', 'C', 'C', 'Reverted', 'C', 'Reverted', 'C', 'Reverted']
#
# OBSERVED STATE: 42.8571
# REWARD: REWARD
# DONE: False
# INFO:  {}
# RDKit ERROR: [23:19:58] Explicit valence for atom # 2 Br, 2, is greater than permitted
# ACTION:  3
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring', 'Br', 'Reverted', 'Br', 'Reverted', 'bracketed atom', 'Br', 'Reverted', 'C', 'C', 'Reverted', 'C', 'Reverted', 'C', 'Reverted', 'Br']
#
# OBSERVED STATE: 37.5
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  0
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring', 'Br', 'Reverted', 'Br', 'Reverted', 'bracketed atom', 'Br', 'Reverted', 'C', 'C', 'Reverted', 'C', 'Reverted', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted']
#
# OBSERVED STATE: 42.8571
# REWARD: REWARD
# DONE: False
# INFO:  {}
# RDKit ERROR: [23:20:00] Explicit valence for atom # 2 Br, 2, is greater than permitted
# ACTION:  2
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring', 'Br', 'Reverted', 'Br', 'Reverted', 'bracketed atom', 'Br', 'Reverted', 'C', 'C', 'Reverted', 'C', 'Reverted', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'C', 'Reverted']
#
# OBSERVED STATE: 42.8571
# REWARD: REWARD
# DONE: False
# INFO:  {}
# RDKit ERROR: [23:20:01] Explicit valence for atom # 2 Br, 2, is greater than permitted
# ACTION:  5
# add ring
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring', 'Br', 'Reverted', 'Br', 'Reverted', 'bracketed atom', 'Br', 'Reverted', 'C', 'C', 'Reverted', 'C', 'Reverted', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'C', 'Reverted', 'ring']
#
# OBSERVED STATE: 42.8571
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  4
# add bracketed atom
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring', 'Br', 'Reverted', 'Br', 'Reverted', 'bracketed atom', 'Br', 'Reverted', 'C', 'C', 'Reverted', 'C', 'Reverted', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'C', 'Reverted', 'ring', 'bracketed atom']
#
# OBSERVED STATE: 42.8571
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  4
# add bracketed atom
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring', 'Br', 'Reverted', 'Br', 'Reverted', 'bracketed atom', 'Br', 'Reverted', 'C', 'C', 'Reverted', 'C', 'Reverted', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'C', 'Reverted', 'ring', 'bracketed atom', 'bracketed atom']
#
# OBSERVED STATE: 42.8571
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  3
# ['Br', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'ring', 'Br', 'Reverted', 'Br', 'Reverted', 'bracketed atom', 'Br', 'Reverted', 'C', 'C', 'Reverted', 'C', 'Reverted', 'C', 'Reverted', 'Br', 'Reverted', 'Br', 'Reverted', 'C', 'Reverted', 'ring', 'bracketed atom', 'bracketed atom', 'C']
#
# OBSERVED STATE: 71.4286
# REWARD: 0
# DONE: True
# INFO:  {}
# Molecule Optimized.
# EPISODE: 2
# Env original state:  None
#
# ACTION:  5
# add ring
# ['ring']
#
# OBSERVED STATE: 0.0
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  1
# ['ring', 'C']
#
# OBSERVED STATE: 14.2857
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  3
# ['ring', 'C', 'C']
#
# OBSERVED STATE: 28.5714
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  0
# ['ring', 'C', 'C', 'C']
#
# OBSERVED STATE: 42.8571
# REWARD: REWARD
# DONE: False
# INFO:  {}
# ACTION:  0
# ['ring', 'C', 'C', 'C', 'Br']
#
# OBSERVED STATE: 100.0
# REWARD: 0
# DONE: True
# INFO:  {}
# Molecule Optimized.
