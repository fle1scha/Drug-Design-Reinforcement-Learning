# %% [markdown]
# # Main class for running the molecule environment

# %%
import gym
import import_ipynb
from gym import wrappers, logger
from MoleculeAgent import MoleculeAgent

# %%
def main():
    env = gym.make("gym_molecule:molecule-v0")
    
    #Create a new Molecule Agent object. 
    agent = MoleculeAgent(env.action_space)
    
    episode_count = 5
    reward = 0
    done = False

    #The 'RL algorithm' learns for 2 episodes of undefined length.
    for i in range(0, episode_count):
        print("EPISODE:", i)
        
        #The env resets.
        ob = env.reset()
        print("Env original state: ", ob)
        
        #While what is True?
        for x in range(10):
            
            
            
            #The agent chooses its action based on the tuple from the current env state.
            action = agent.act(ob, reward, done)
            print("Agent's chosen action: ", action) 
            
            #The new tuple is returned because the env has considered the agent's action.
            ob, reward, done, _ = env.step(action)
            print("Env new state:", ob, "Reward to agent:",reward, "Done:",done, "Info: ", _)
            
            #The env renders. 
            env.render()
            
            
        
            #If the env reaches a terminating state, the current iteration ends and the next 
            #episode begins. 
            """"if done:
                print()
                break"""
        
    env.close()
    
    
if __name__ == '__main__':
    main()
# Out:
# EPISODE: 0
# Env original state:  [0. 0. 0.]
# Agent's chosen action:  3
# Env new state: [0. 1. 0.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  2
# Env new state: [0. 2. 0.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  0
# Env new state: [1. 2. 0.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  0
# Env new state: [2. 2. 0.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  5
# Env new state: [2. 2. 1.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  5
# Env new state: [2. 2. 2.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  1
# Env new state: [3. 2. 2.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  5
# Env new state: [3. 2. 3.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  1
# Env new state: [4. 2. 3.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  4
# Env new state: [4. 2. 4.] Reward to agent: 0 Done: True Info:  {}
# EPISODE: 1
# Env original state:  [0. 0. 0.]
# Agent's chosen action:  0
# Env new state: [1. 0. 0.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  2
# Env new state: [1. 1. 0.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  2
# Env new state: [1. 2. 0.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  4
# Env new state: [1. 2. 1.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  5
# Env new state: [1. 2. 2.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  0
# Env new state: [2. 2. 2.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  4
# Env new state: [2. 2. 3.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  2
# Env new state: [2. 3. 3.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  3
# Env new state: [2. 4. 3.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  3
# Env new state: [2. 5. 3.] Reward to agent: 0 Done: True Info:  {}
# EPISODE: 2
# Env original state:  [0. 0. 0.]
# Agent's chosen action:  0
# Env new state: [1. 0. 0.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  5
# Env new state: [1. 0. 1.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  0
# Env new state: [2. 0. 1.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  5
# Env new state: [2. 0. 2.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  5
# Env new state: [2. 0. 3.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  3
# Env new state: [2. 1. 3.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  5
# Env new state: [2. 1. 4.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  1
# Env new state: [3. 1. 4.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  5
# Env new state: [3. 1. 5.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  0
# Env new state: [4. 1. 5.] Reward to agent: 0 Done: True Info:  {}
# EPISODE: 3
# Env original state:  [0. 0. 0.]
# Agent's chosen action:  1
# Env new state: [1. 0. 0.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  4
# Env new state: [1. 0. 1.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  5
# Env new state: [1. 0. 2.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  1
# Env new state: [2. 0. 2.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  1
# Env new state: [3. 0. 2.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  0
# Env new state: [4. 0. 2.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  5
# Env new state: [4. 0. 3.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  2
# Env new state: [4. 1. 3.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  2
# Env new state: [4. 2. 3.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  5
# Env new state: [4. 2. 4.] Reward to agent: 0 Done: True Info:  {}
# EPISODE: 4
# Env original state:  [0. 0. 0.]
# Agent's chosen action:  3
# Env new state: [0. 1. 0.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  3
# Env new state: [0. 2. 0.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  0
# Env new state: [1. 2. 0.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  5
# Env new state: [1. 2. 1.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  3
# Env new state: [1. 3. 1.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  2
# Env new state: [1. 4. 1.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  1
# Env new state: [2. 4. 1.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  2
# Env new state: [2. 5. 1.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  1
# Env new state: [3. 5. 1.] Reward to agent: 0 Done: True Info:  {}
# Agent's chosen action:  4
# Env new state: [3. 5. 2.] Reward to agent: 0 Done: True Info:  {}
