# %% [markdown]
# # Main class for running the molecule environment

# %%
import gym
from gym import wrappers, logger
from MoleculeAgent import MoleculeAgent
from rdkit import Chem
from rdkit.Chem import AllChem, Draw
import matplotlib.pyplot as plt
# TODO: Render as a main function too
# Render toggled in the main class 
# find the correct time delay
# 
# Add pop in modifications

# %%
def isValid(mol):
    try:
        molecule = Chem.MolFromSmiles(mol)
        smiles = Chem.MolToSmiles(molecule, isomericSmiles=True)
    except:
        print("Entered input is chemically invalid")
        return False
    else:
        return True


def main():
    print("Welcome to TEDD, the Training Environment for Drug Discovery.")
    print("In order to run the environment, you will need to input a starting molecule, a target molecule and an optimisation goal.")
  
    # determine starting molecule
    while True:
        print("Step 1) Choose starting molecule: \nInput ‘1’ to choose a CARBON molecule.\nInput ‘2’ to choose a RANDOM molecule.")
        starting_molecule = input("Input: ")
        if not(starting_molecule == "1" or starting_molecule == "2"):
            print("Incorrect Input.\n")
        elif starting_molecule == '1':
            starting_molecule = "C" # get carbon molecule 
            break
        else:
            starting_molecule = "1" # get random molecule 
            break

    # determine target molecule
    while True:
        print("\nStep 2) Choose target molecule: \nInput ‘1’ to SPECIFY a molecule.\nInput ‘2’ to choose a RANDOM molecule.")
        target_molecule = input("Input: ")
        if not(target_molecule == '1' or target_molecule == '2'):
            print("Incorrect Input.\n")
        elif target_molecule == '1':
            print("Input the target molecule.")
            target_molecule = input("Input: ")
            if isValid(target_molecule): # check validity of molecule (?)
                break
            else:
                print("Incorrect Input.\n")
        else:
            target_molecule = "1" # get random molecule 
            break

    # determine optimisation goal
    while True:
        print("\nStep 3) Choose optimisation goal: \nInput a floating-point value between 0 and 1.")
        optimisation_goal = input("Input: ")
        try:
            optimisation_goal = float(optimisation_goal)
            if optimisation_goal < 0 or optimisation_goal > 100:
                print("Incorrect Input.\n")
            else:
                break
        except:
            print("Incorrect Input.\n")

    env = gym.make("gym_molecule:molecule-v0", start = starting_molecule, target = target_molecule, goal = optimisation_goal)
                
    print("Environment initialiased.")
     
    agent = MoleculeAgent(env.observation_space, env.action_space) # Create a new Molecule Agent object.
    
    
    episode_count = 2
    reward = 0
    done = False

    
    
    for episode in range(1,5):

        state = env.reset()
        print("Episode: " + str(episode) + ", Starting State: " + str(state))

        for step in range(1,21):
            action = agent.act(state, reward, done)
            print("Action: ", action) 

            state_next, reward, done, info = env.step(action)
            print("State:", state_next, "\nReward:", reward, "\nDone:", done,"\nInfo: ")

            # agent.remember(state, action, reward, state_next, done)
            state = state_next

            env.render()

            if done:
                print("Optimisation Goal Achieved - Episode: " + str(episode) + ", Step: " + str(step) + ", Similarity %: " + str(state))
                break  
        
    env.close()
            
    


        
    
    
if __name__ == '__main__':
    main()

# Aspirin: O=C(C)Oc1ccccc1C(=O)O
# Start with: Oc1ccccc1C
# Out:
# Welcome to TEDD, the Training Environment for Drug Discovery.
# In order to run the environment, you will need to input a starting molecule, a target molecule and an optimisation goal.
# Step 1) Choose starting molecule:
# Input ‘1’ to choose a CARBON molecule.
# Input ‘2’ to choose a RANDOM molecule.
# Input: 2
#
# Step 2) Choose target molecule:
# Input ‘1’ to SPECIFY a molecule.
# Input ‘2’ to choose a RANDOM molecule.
# Input: 2
#
# Step 3) Choose optimisation goal:
# Input a floating-point value between 0 and 1.
# Input: 45
# Environment initialiased.
# Episode: 1, Starting State: 0.0
# Action:  3
# State: 0.0
# Reward: 0
# Done: False
# Info:
# Action:  1
# State: 0.0
# Reward: 0
# Done: False
# Info:
# Action:  3
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:27] Explicit valence for atom # 1 O, 4, is greater than permitted
# Action:  2
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:27] Explicit valence for atom # 2 F, 3, is greater than permitted
# Action:  5
# State: 0.0
# Reward: -10
# Done: False
# Info:
# Action:  0
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:28] Explicit valence for atom # 2 F, 2, is greater than permitted
# Action:  2
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:29] Explicit valence for atom # 2 F, 3, is greater than permitted
# Action:  5
# State: 0.0
# Reward: -10
# Done: False
# Info:
# Action:  2
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:30] Explicit valence for atom # 2 F, 4, is greater than permitted
# Action:  2
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:31] Explicit valence for atom # 2 F, 4, is greater than permitted
# Action:  1
# State: 0.4274
# Reward: 0
# Done: False
# Info:
# Action:  2
# State: 0.4274
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:32] Explicit valence for atom # 3 F, 3, is greater than permitted
# Action:  3
# State: 0.4274
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:33] Explicit valence for atom # 0 O, 3, is greater than permitted
# Action:  1
# State: 0.6369
# Reward: 0
# Done: False
# Info:
# Action:  0
# State: 0.6369
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:34] Explicit valence for atom # 4 F, 2, is greater than permitted
# Action:  5
# State: 0.6369
# Reward: -10
# Done: False
# Info:
# Action:  5
# State: 0.6369
# Reward: -10
# Done: False
# Info:
# Action:  2
# State: 0.6369
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:35] Explicit valence for atom # 4 F, 3, is greater than permitted
# Action:  4
# State: 0.6369
# Reward: -10
# Done: False
# Info:
# Action:  0
# State: 0.6369
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:36] Explicit valence for atom # 4 F, 2, is greater than permitted
# Episode: 2, Starting State: 0.0
# Action:  2
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:37] Explicit valence for atom # 0 F, 3, is greater than permitted
# Action:  4
# State: 0.0
# Reward: -10
# Done: False
# Info:
# Action:  0
# State: 0.0
# Reward: 0
# Done: False
# Info:
# Action:  4
# State: 0.0
# Reward: 0
# Done: False
# Info:
# Action:  2
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:39] Explicit valence for atom # 1 O, 4, is greater than permitted
# Action:  3
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:39] Explicit valence for atom # 1 F, 3, is greater than permitted
# Action:  4
# State: 0.0
# Reward: -10
# Done: False
# Info:
# Action:  3
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:40] Explicit valence for atom # 1 F, 3, is greater than permitted
# Action:  1
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:41] Explicit valence for atom # 1 F, 2, is greater than permitted
# Action:  3
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:42] Explicit valence for atom # 1 F, 2, is greater than permitted
# Action:  0
# State: 0.0
# Reward: 0
# Done: False
# Info:
# Action:  0
# State: 0.4274
# Reward: 0
# Done: False
# Info:
# Action:  0
# State: 0.6369
# Reward: 0
# Done: False
# Info:
# Action:  1
# State: 0.6369
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:45] Explicit valence for atom # 1 F, 2, is greater than permitted
# Action:  0
# State: 0.8439
# Reward: 0
# Done: False
# Info:
# Action:  1
# State: 0.8439
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:46] Explicit valence for atom # 1 F, 2, is greater than permitted
# Action:  1
# State: 0.8439
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:46] Explicit valence for atom # 1 F, 2, is greater than permitted
# Action:  0
# State: 1.4493
# Reward: 0
# Done: False
# Info:
# Action:  0
# State: 2.2403
# Reward: 0
# Done: False
# Info:
# Action:  4
# State: 2.2403
# Reward: 0
# Done: False
# Info:
# Episode: 3, Starting State: 0.0
# Action:  1
# State: 0.0
# Reward: 0
# Done: False
# Info:
# Action:  4
# State: 0.0
# Reward: 0
# Done: False
# Info:
# Action:  0
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:50] Explicit valence for atom # 1 F, 2, is greater than permitted
# Action:  3
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:51] Explicit valence for atom # 0 O, 3, is greater than permitted
# Action:  4
# State: 0.0
# Reward: -10
# Done: False
# Info:
# Action:  4
# State: 0.0
# Reward: -10
# Done: False
# Info:
# Action:  5
# State: 0.0
# Reward: -10
# Done: False
# Info:
# Action:  3
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:53] Explicit valence for atom # 1 O, 4, is greater than permitted
# Action:  5
# State: 0.0
# Reward: -10
# Done: False
# Info:
# Action:  0
# State: 0.0
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:54] Explicit valence for atom # 1 F, 2, is greater than permitted
# Action:  4
# State: 0.0
# Reward: -10
# Done: False
# Info:
# Action:  1
# State: 0.0
# Reward: 0
# Done: False
# Info:
# Action:  5
# State: 0.0
# Reward: 0
# Done: False
# Info:
# Action:  1
# State: 0.4255
# Reward: 0
# Done: False
# Info:
# Action:  3
# State: 0.8421
# Reward: 0
# Done: False
# Info:
# Action:  5
# State: 0.8421
# Reward: 0
# Done: False
# Info:
# Action:  0
# State: 0.8421
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:58] Explicit valence for atom # 4 F, 2, is greater than permitted
# Action:  3
# State: 0.8421
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:58] Explicit valence for atom # 1 O, 5, is greater than permitted
# Action:  1
# State: 0.8421
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:59] Explicit valence for atom # 1 O, 3, is greater than permitted
# Action:  2
# State: 0.8421
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:50:59] Explicit valence for atom # 4 F, 3, is greater than permitted
# Episode: 4, Starting State: 0.0
# Action:  0
# State: 0.0
# Reward: 0
# Done: False
# Info:
# Action:  0
# State: 0.431
# Reward: 0
# Done: False
# Info:
# Action:  1
# State: 0.431
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:51:01] Explicit valence for atom # 1 F, 2, is greater than permitted
# Action:  4
# State: 0.431
# Reward: -10
# Done: False
# Info:
# Action:  0
# State: 1.5054
# Reward: 0
# Done: False
# Info:
# Action:  0
# State: 1.9108
# Reward: 0
# Done: False
# Info:
# Action:  3
# State: 1.9108
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:51:03] Explicit valence for atom # 1 F, 4, is greater than permitted
# Action:  0
# State: 1.8868
# Reward: 0
# Done: False
# Info:
# Action:  4
# State: 1.8868
# Reward: 0
# Done: False
# Info:
# Action:  4
# State: 1.8868
# Reward: 0
# Done: False
# Info:
# Action:  3
# State: 1.8868
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:51:05] Explicit valence for atom # 1 F, 4, is greater than permitted
# Action:  0
# State: 2.0833
# Reward: 0
# Done: False
# Info:
# Action:  5
# State: 2.0833
# Reward: 0
# Done: False
# Info:
# Action:  0
# State: 2.6694
# Reward: 0
# Done: False
# Info:
# Action:  5
# State: 2.6694
# Reward: 0
# Done: False
# Info:
# Action:  2
# State: 2.6694
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:51:09] Explicit valence for atom # 7 O, 3, is greater than permitted
# Action:  2
# State: 3.2258
# Reward: 0
# Done: False
# Info:
# Action:  4
# State: 3.2258
# Reward: 0
# Done: False
# Info:
# Action:  1
# State: 3.2258
# Reward: -10
# Done: False
# Info:
# RDKit ERROR: [10:51:11] Explicit valence for atom # 1 F, 2, is greater than permitted
# Action:  2
# State: 3.9526
# Reward: 0
# Done: False
# Info:

# %% [markdown]
# ##
